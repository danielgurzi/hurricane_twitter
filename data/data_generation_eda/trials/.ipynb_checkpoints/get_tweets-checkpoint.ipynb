# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from IPython.display import display, Markdown, Latex
import GetOldTweets3 as got
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS
from nltk.corpus import stopwords
import datetime


pd.set_option("max_rows", 75)

# %% [markdown]
# ## Function to Pull Tweets

# %%
# This function uses Reem's GOT3 code to import tweets given query, date range and number of tweets and saves it to a csv file

def get_tweets(query,start='2006-03-21',end=datetime.date.today().strftime("%Y-%m-%d"),maxtweets=1000):
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch(query)\
                                               .setSince(start)\
                                               .setUntil(end)\
                                               .setMaxTweets(maxtweets)
    tweet = got.manager.TweetManager.getTweets(tweetCriteria)

    tweet_dict = tweetCriteria.__dict__
    file_name = (tweet_dict['querySearch']+\
                 tweet_dict['since']+\
                 tweet_dict['until']).replace(" ","_")   
    df = pd.DataFrame([t.__dict__ for t in tweet])
    return df.to_csv(f'./data/{query}_{maxtweets}.csv', index=False)

# %% [markdown]
# ## Function to pull word frequency from tweet csv

# %%
# this is the stop words list for the countvectorizer
custom_words = list(set(
    list(ENGLISH_STOP_WORDS) + list(stopwords.words('english')) + 
    ['and','of','for','the','com','amp','https','http']))

# This function outputs a dataframe with text used by good handles and top text that isn't used by good handles
def frequency_words(df, handles):
    # dataframe of tweets from friendly handles given approved by client
    info = tweets[tweets['username'].str.lower().isin([x.lower() for x in handles])]
    #instantiate countvect for good info and transform tweets from safe_handles to dataframe
    info_cvec = CountVectorizer(stop_words = custom_words)
    info_cv = info_cvec.fit_transform(info.text)
    info_words = pd.DataFrame(info_cv.toarray(), columns = info_cvec.get_feature_names())
    info_count = info_words.sum().sort_values(ascending=False)
    
    #create new word list with words used by verified accounts
    new_stops = custom_words + info_cvec.get_feature_names()
    misinfo = tweets[~tweets['username'].str.lower().isin([x.lower() for x in handles])]

    misinfo_cvec = CountVectorizer(stop_words = new_stops)
    misinfo_cv = misinfo_cvec.fit_transform(misinfo.text)
    misinfo_words = pd.DataFrame(misinfo_cv.toarray(), columns = misinfo_cvec.get_feature_names())
    
    misinfo_count = misinfo_words.sum().sort_values(ascending=False)
    return info_count, misinfo_count

# %% [markdown]
# ## Set Disaster Info

# %%
search = 'hurricaneharvey'
start_date = '2017-07-01'
end_date = '2017-10-01'
tweet_count = 10000
harvey_handles = ['fema','usaid']
mendocino_handles = ['fema','usaid','calfire','MendoSheriff','calfire_meu', 'cagovernor','FEMARegion9','r5_fire_news', 'MendocinoNF']
aussie_handles = ['afacnews','act_esa','abcemergency','frnsw','qldfes','cfsalerts']

good_handles = aussie_handles

# %% [markdown]
# ### Run function to pull tweets with above parameters and save as CSV

# %%
# pull tweets with keyword search, optional: start and end dates and maxtweets to pull(default is 1000)
get_tweets(search,start=start_date, end= end_date, maxtweets=tweet_count)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=hurricaneharvey%20since%3A2017-07-01%20until%3A2017-10-01&src=typd
# Traceback (most recent call last):
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/GetOldTweets3/manager/TweetManager.py", line 343, in getJsonResponse
#     response = opener.open(url)
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 429: Too Many Requests
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-283-775580ecdd5c>", line 2, in <module>
#     get_tweets(search,start=start_date, end= end_date, maxtweets=tweet_count)
#   File "<ipython-input-125-93a2747e5168>", line 6, in get_tweets
#     tweet = got.manager.TweetManager.getTweets(tweetCriteria)
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/GetOldTweets3/manager/TweetManager.py", line 65, in getTweets
#     json = TweetManager.getJsonResponse(tweetCriteria, refreshCursor, cookieJar, proxy, user_agent, debug=debug)
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/GetOldTweets3/manager/TweetManager.py", line 348, in getJsonResponse
#     sys.exit()
# SystemExit
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/danielgurzi/opt/anaconda3/envs/dsi/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# An exception has occurred, use %tb to see the full traceback.
#
# ---------------------------------------------------------------------------
#
# During handling of the above exception, another exception occurred:
#
# SystemExit

# %% [markdown]
# ### Import CSV back into Jupyter as a DataFrame

# %%
# pull csv of tweets back in as a dataframe for parsing
tweets = pd.read_csv(f'./data/{search}_{tweet_count}.csv')

# drop rows with NaN in the text column
tweets.dropna(axis=0,subset = ['text'],inplace=True)
tweets.shape
# Out:
# (10000, 15)

# %%
retweets = pd.read_csv(f'./data/{search}_retweet.csv')

# %%
retweets.shape
# Out:
# (10000, 15)

# %% [markdown]
# ## RETWEETS

# %%
# take each tweet and multiply the row by the number of retweets as a weight for that tweet
tweets = pd.read_csv(f'./data/{search}_{tweet_count}.csv')
# drop any rows with empty tweets
tweets.dropna(axis=0,subset = ['text'],inplace=True)
print(f' original dataframe shape: {tweets.shape}')

for ind, row in retweets.iterrows():
    for rt in range(0,retweets['retweets'].iloc[ind]):
        retweets = retweets.append(pd.Series(row,index=test.columns))
print(f' new shape with retweets duplicated: {retweets.shape}')
# Out:
# (30799, 16)

# %%
retweets.to_csv('./data/{search}_retweets.csv',index=False)

# %%
retweets.loc[8618]
# Out:
# Unnamed: 0                                                     8618
# username                                                CALFIRE_MEU
# to                                                              NaN
# text              Incident Update #RanchFire #RiverFire is now t...
# retweets                                                         48
# favorites                                                        44
# replies                                                           1
# id                                              1023112231397949440
# permalink         https://twitter.com/CALFIRE_MEU/status/1023112...
# author_id                                                3962153832
# date                                      2018-07-28 07:45:39+00:00
# formatted_date                       Sat Jul 28 07:45:39 +0000 2018
# hashtags                    #RanchFire #RiverFire #MendocinoComplex
# mentions                                                          0
# geo                                                             NaN
# urls                                                            NaN
# Name: 8618, dtype: object

# %%
# retweets['mentions'].fillna(0, inplace=True)
texts = retweets[retweets['text'].str.contains("Just a quick FYI peeps.")]
texts.head()
# Out:
#       Unnamed: 0       username   to  \
# 8616        8616  Jasamsdestiny  NaN
#
#                                                    text  retweets  favorites  \
# 8616  Just a quick FYI peeps. Ranch and River have m...         5          3
#
#       replies                   id  \
# 8616        4  1023117759104860160
#
#                                               permalink  author_id  \
# 8616  https://twitter.com/Jasamsdestiny/status/10231...  129877411
#
#                            date                  formatted_date  \
# 8616  2018-07-28 08:07:37+00:00  Sat Jul 28 08:07:37 +0000 2018
#
#                                                hashtags mentions  geo urls
# 8616  #MendocinoComplex #RiverFire #Ranchfire #Mendo...        0  NaN  NaN

# %%
tweets = pd.read_csv('../workflow/data/hurricaneharvey/twitter_retrieval/hurricaneharvey_10000.csv')

# %%
tweets['hashtags']
# Out:
# 0                                         #HurricanHarvey
# 1                          #HurricanHarvey #HoustonStrong
# 2                                    #cat #HurricanHarvey
# 3                               #MTPDaily #HurricanHarvey
# 4                                         #hurricanharvey
#                               ...
# 9995                    #HurricanHarvey #HurricaineHarvey
# 9996                     #HurricanHarvey #HurricaneHarvey
# 9997                               #HurricanHarvey #Trump
# 9998    #breaking #HurricanHarvey #harvey #hurricane #...
# 9999                                      #HurricanHarvey
# Name: hashtags, Length: 10000, dtype: object

# %%
# Function to get hashtags that are also used with initial hashtag
def new_hashes(df_series):
    hashtags=[]
    for ht in df_series:
        for h in str(ht).split(' #'):
            hashtags.append(h.replace('#',''))
    return set(hashtags)
    
new_hashes(tweets['hashtags'])
# Out:
# {'ParisAccord',
#  'photojournalism',
#  'PrayForTexas',
#  'SaveMyCity',
#  'retailers',
#  'Jesus',
#  'Pardon',
#  'Michigan',
#  'LongIsland',
#  'HoustonFlooding',
#  'Humble',
#  'staystrongtexas',
#  'nopower',
#  'LasVegas',
#  'CNN',
#  'Uber',
#  'ew',
#  'disasterstudies',
#  'boats',
#  'MakingAmericaSafeAgain',
#  'Charolettesville',
#  'coconut',
#  'pioneers',
#  'POTUS',
#  'AlonsoGuillen',
#  'fridaynightdump',
#  'OldKaty',
#  'RescueDogs',
#  'sosad',
#  'WeAreWatauga',
#  'ittakesavillage',
#  'MirandaLambert',
#  'dayofgiving',
#  'Irmaonitsway',
#  'challenge',
#  'Wireless',
#  'CreditUnion',
#  'mirandalambert_muttnation',
#  'RealEstatePlace',
#  'idp',
#  'Onnit',
#  'twitch',
#  'jjwatt',
#  'ShoutOut',
#  'LoveTrumpsStorm',
#  'NewBraunfels',
#  'hopefulhippies',
#  'TacoTuesday',
#  'irony',
#  'KHOU',
#  'blueshedstrong',
#  'drones',
#  'angryplanet',
#  'SolarEclispe2017',
#  'helpingthoseinneed',
#  'firefighters',
#  'Alief',
#  'elite',
#  'sunshinefinally',
#  'HarveyFlooding',
#  'thinkaboutthat',
#  'YouNeedAHashtag',
#  'Victoria',
#  'matthewstafford',
#  'SWITZERLAND',
#  'CompassNorth',
#  'StayStrongTexas',
#  'losjacales',
#  'OnePride',
#  'igor',
#  'Volatix',
#  'DenverharborTx',
#  'wewillrebuild',
#  'freehugs',
#  'handlettering',
#  'GameOfThrones',
#  '19thamendment',
#  'racism',
#  'movedelayed',
#  'allnightlong',
#  'Wafflehouse',
#  'Bakery',
#  'MexicoCityearthquake',
#  'give',
#  'TexasFlooding',
#  'TexasLouisiana',
#  'gop',
#  'DraftBernie',
#  'whoop',
#  'pancreaticcancer',
#  'NoWallSaveHouston',
#  'FearOfGod',
#  'clinton',
#  'SAVIcontrols',
#  'blooddrive',
#  'writers',
#  'football',
#  'gonzalestexas',
#  'Hollywood',
#  'HuracanMariaPR',
#  'mccloud',
#  'PeopleSkills',
#  'Floodling',
#  'Extreme',
#  'familybusinesses',
#  'houston',
#  'cripple',
#  'MLB',
#  'noschoolforaweek',
#  'Nuclear',
#  'PowerOutages',
#  'Tamuk',
#  'lotsoflove',
#  'PROJECTS',
#  'fazeup',
#  'bravery',
#  'rocketspirit',
#  'haarp',
#  'HelpTexas',
#  'house',
#  'seedandspark',
#  'Storm',
#  'Americans',
#  'Applefest',
#  'JeffPiotrowski',
#  'noexcusses',
#  'TexasDayOfPrayer',
#  'comehellorhighwater',
#  'trumpregrets',
#  'yoocan',
#  'texasbbqing',
#  'Compassion',
#  'DONATETODAY',
#  'news_analysis',
#  'GorkaOut',
#  'Keuchel',
#  'Lord',
#  'Swampy',
#  'Hurricaneirma',
#  'FantasyFootball',
#  'video',
#  'readersareleader',
#  'USAR',
#  'ISTE17',
#  'ATDColleges',
#  'redeemedministries',
#  'charleston',
#  'SheriffJoeArpaio',
#  'Antifa',
#  'labordayweekend',
#  'Debt',
#  'Karachi',
#  'Hurricane',
#  'economy',
#  'Queens',
#  'TORNADO',
#  'Charity',
#  '7InchHeels',
#  'SB4',
#  'TexasNeedsRescuersNotTrump',
#  'staywoke',
#  'lol',
#  'WhiteTerrorism',
#  'casinotime',
#  'impeachtrump',
#  'PolkCounty',
#  'imagination',
#  'ArmyStrong',
#  'plastic',
#  'ArpaioPardon',
#  'status',
#  'nikkieistherealMVP',
#  'EarthquakeHarvey',
#  'besafehouston',
#  'TexasNavy',
#  'OH2TX',
#  'donations',
#  'Americares',
#  'janiedurbin',
#  'freshmanadvice',
#  'HelpForAnimals',
#  'HoustonTexas',
#  'askfb',
#  'badbusiness',
#  'personnel',
#  'DoneWithHurricanes',
#  'abouttobehomeless',
#  'SebastianGorka',
#  'victoriatx',
#  'flood2017',
#  'MidnightTexas',
#  'tweetliketrump',
#  'MayweatherMcGregor',
#  'HurricaneIrma2017',
#  'NWS',
#  'Youtubecensorship',
#  'Destroying',
#  'lightcompany',
#  'NICU',
#  'BreadofLife',
#  'gospel',
#  'MoreOfUsThanYou',
#  'Cyclones',
#  'SB4IsHate',
#  'Hurricaine',
#  'ProfessionalLiability',
#  'thelittlethings',
#  'croquettes',
#  'jeepharvey',
#  'shameonTrump',
#  'msnbc',
#  'badwording',
#  'AvaBlu',
#  'WaterIsLife',
#  'gridstudy',
#  'World',
#  'GBA',
#  'BIGLY',
#  'everythingorange',
#  'boxing',
#  'inlove',
#  'HB1174',
#  'con',
#  'FakeTrending',
#  'Leftist',
#  'TaylorSwiftDelivery',
#  'Summer2017',
#  'DerrickFreeman',
#  'CCISDCares',
#  'hopeful',
#  'Catfish',
#  'DREAMers',
#  'baytown',
#  'backtonormal',
#  'cometogether',
#  'facebook',
#  'MOTHERNATURE',
#  'Ocoee',
#  'HARVEY',
#  'PrayForMatagordaCounty',
#  'WindFarms',
#  'NFL',
#  'NotAGoodPerson',
#  'HoustonStrong',
#  'PromisesKept',
#  'Loisianna',
#  'Libtard',
#  'texasflooding',
#  'kirkwood',
#  'HopeAfterHarvey',
#  'FoxNews',
#  'Nazi',
#  'HoustonPets',
#  'CapeCod',
#  'whirlietheclown',
#  'lovethis',
#  'PresidentPence',
#  'Fracking',
#  'nationaldayofprayer',
#  'Flooding',
#  'St',
#  'DTLA',
#  'CharityLivestream',
#  'Bastrop',
#  'selenamemorial',
#  'wefeelyourpain',
#  'Shameless',
#  'globalWarming',
#  'heroes',
#  'Potus',
#  'trumpisaracist',
#  'ReliefForHarvey',
#  'MegaCare',
#  'Beyonce',
#  'Sharing',
#  'aid',
#  'ToxicForDogs',
#  'cartoon',
#  'fire',
#  'firefighter',
#  'trump',
#  'MuellerIsComing',
#  'staysafey',
#  'FilltheTruck',
#  'Fox35',
#  'mormon',
#  'BoogieCertified',
#  'MuellerTime',
#  'PNW',
#  'heartiscleburne',
#  'ThadCochran',
#  'igotyou',
#  'wemakegoodthingshappen',
#  'russianinvestigation',
#  'lightning',
#  'posts',
#  't1d',
#  'MotherNature',
#  'LA',
#  'cloudseeding',
#  'ThxLakersfortheOnehundredthousanfDollars',
#  'DeuceFerruccio',
#  'Berkeley',
#  'childnutrition',
#  'Respect',
#  'WeRiseByLiftingOthers',
#  '10over10',
#  'aokithavixen',
#  'IdiotInChief',
#  'HOH',
#  'hunkerdownhtown',
#  'VMAs',
#  'MSP',
#  'Afghan',
#  'APFED',
#  'hurricaneflood',
#  'BlackLivesMatter',
#  'AfternoonTakever',
#  'useyourhead',
#  'TBATs',
#  'FF',
#  'PLLEndGame',
#  'HoustonRelief',
#  'MyMantra',
#  'amjoy',
#  'IslamicReliefUSA',
#  'YellowSubmarine',
#  'hurricaneIrma',
#  'TrumpvsObama',
#  'communication',
#  'Jeff',
#  'TAMUCC',
#  'LightsOut',
#  'MegaChurch',
#  'Haiti',
#  'houstonhurricanes',
#  'cattledrive',
#  'htx',
#  'crazy',
#  'rebuild',
#  'seattlesmoke',
#  'AchievementUnlocked',
#  'wastewater',
#  'HelpForHarvey',
#  'grifterinchief',
#  'ImpeachTrumpPence',
#  'keyallegro',
#  'KILLED',
#  'rainraingoaway',
#  'Disgraceful',
#  'stillraining',
#  'HurricaneHarveyReliefChallenge',
#  'matthew25ministries',
#  'FactsMatter',
#  'CIO',
#  'payup',
#  'thishurricaneisnojoke',
#  'HarveyRecovery',
#  'planet',
#  'bettertogether',
#  'somewhereinhouston',
#  'DePaul',
#  'politicalagenda',
#  'IWishIdNever',
#  'houstonweather',
#  'Sharethelove',
#  'Atxfloods',
#  'oil',
#  'Africa',
#  'cmworld',
#  'collaboration',
#  'AllLivesMatter',
#  'hotel',
#  'TraitorTrump',
#  'Aztectribe',
#  'HelpforHarvey',
#  'freepress',
#  'Sheldon',
#  'pagan',
#  'PrayforRockport',
#  'franklins',
#  'alternativefacts',
#  'beautiful',
#  'C27J',
#  'Flood',
#  'rescues',
#  'hurricanclouds',
#  'WeAreAllTexans',
#  'LDS',
#  'southwesthouston',
#  'attention',
#  'saveJeff',
#  'MariaHurricane',
#  'communisttwitter',
#  'trendingorange',
#  'BePrepared',
#  'IRLANDA',
#  'PoeticJustice',
#  'harveyhouston',
#  'HurricanSandy',
#  'AnimalRescuers',
#  'Congressionaldelegations',
#  'Inspire',
#  'FloodingHouston',
#  'AdvocacySinFronteras',
#  'severe_storms',
#  'CA',
#  'AnnieTheRescueDog',
#  'Texasstrong',
#  'Socialism',
#  'MayweatherMacGregor',
#  'NorthKorea',
#  'curr',
#  'jamesstewart',
#  'fridayreads',
#  'Harveycnn',
#  'america',
#  'cctx',
#  'WomenEqualityDay',
#  'quibit',
#  'weather',
#  'Brazil',
#  'MSNBC',
#  'ct',
#  'MayweathervMcgregor',
#  'impact',
#  'Periscope',
#  'NorthTX',
#  'displacedpets',
#  'InOurPrayers',
#  'PSU',
#  'ChickenTacos',
#  'Dads',
#  'Jihad',
#  'BoostVibes',
#  'Bestill',
#  'detective',
#  'coal',
#  'AVL',
#  'MCC',
#  'GIS',
#  'fema',
#  'harveyflooding',
#  'smbhou',
#  'HurricaneHarvey2017',
#  'ZeroHedge',
#  'wasteful',
#  'Hurricanirma',
#  'theatre',
#  'classof2021',
#  'BoycottNFL',
#  'savememories',
#  'TurnAroundDontDrown',
#  'TexasRelief',
#  'arpaio',
#  'CampDavid',
#  'Blankets',
#  'corporateirresponsibility',
#  'prayer',
#  'ducttapefixeseverything',
#  'colescrossing',
#  'UTAHvsBYU',
#  'pollution',
#  'WEthePeople',
#  'extremeweather',
#  'MEDIA',
#  'therightthingtodo',
#  'netflix',
#  'Caribbean',
#  'confederatestatues',
#  'wall',
#  'GettingThingsDone',
#  'thatryhmes',
#  'SlowCommute',
#  'Crude',
#  'dogsoftwitter',
#  'theyneedhelp',
#  'cities',
#  'Statues',
#  'SupportImportantCause',
#  'PortLavaca',
#  'victimes',
#  'PrayaForAmerica',
#  'GMN',
#  'Donating',
#  'LAHarveyRelief',
#  'Eventplanners',
#  'VoiceUP',
#  'Medicos',
#  'weareAP',
#  'ALVTodoS',
#  'LawAndOrder',
#  'fridayvibes',
#  'staysafeatx',
#  'urgent',
#  'Copernicus',
#  'Rocket',
#  'Resign',
#  'IfTheEarthCouldTalk',
#  'UPDATE',
#  'ManCity',
#  'influence',
#  'breadtwitter',
#  'RakeItInSweepstakes',
#  'Nonprofit',
#  'Job',
#  'HoustonBeSafe',
#  'EyeWall',
#  'together',
#  'Animals',
#  'LiveFruitFull',
#  'WAKEUPORDIESLEEP',
#  'CuomoPrimeTime',
#  'TexasFloodRecoveryStrong',
#  'charlatan',
#  'CISO',
#  'JoelOsteen',
#  'Huracan',
#  'Indivisible',
#  'kevinheartchallenge',
#  'TEXASUP',
#  'NEWSCENTERMaine',
#  'DemForce',
#  'Hypocrite',
#  'NexstarHarvey',
#  'shockprevention',
#  'donatehurricaneharvey',
#  'PDAztecpride',
#  'CharlieHebdo',
#  'donoharm',
#  'Conroe',
#  'nj',
#  'CensureTrump',
#  'TEXASBREAKINGNEWS',
#  'Arpiao',
#  'Patriots',
#  'USNavy',
#  'ShepardSmith',
#  'fontcandy',
#  'genocide',
#  'HarrisCounty',
#  'HarveyParty',
#  'mississippi',
#  'wecandothis',
#  'matrixplus',
#  'goodsamaritans',
#  'Buda',
#  'Floods',
#  'teamSAVI',
#  'TODAYinLA',
#  'HopeRide',
#  'huston',
#  'Houwx',
#  'STAYGRINDING',
#  'FridayNightNewsDump',
#  'nasa',
#  'k9',
#  'MaydeStrong',
#  'puglife',
#  'securitycamera',
#  'BeSafe',
#  'HurricaneKatrina',
#  'globalwarming',
#  'thinkingofmyloveones',
#  'canerosso',
#  'NashvilleStatement',
#  'pardonsRacistConvict',
#  'publichealth',
#  'NationalDisaster',
#  '1u',
#  'sciencematters',
#  'HurracaineIrma',
#  'fallenangeltattoos',
#  'kevinhartchallenge',
#  'norainhurricane',
#  'sotired',
#  'progressive',
#  'screenshotsaturday',
#  'denial',
#  'SylvesterTurner',
#  'books',
#  'Carnival',
#  'TXnotWall',
#  'ny',
#  'weatherweapons',
#  'heb',
#  'USA',
#  'charitytuesday',
#  'Cemexusa',
#  'txwx',
#  'donateaphoto',
#  'Houstonfloods1',
#  'heros',
#  'HuricaneIrma',
#  'HURRICANHARVEY',
#  'BrokenWindowFallacy',
#  'bff',
#  'TrumpHaiku',
#  'Stargate',
#  'LOVE_YOURSELF',
#  'santafe',
#  'animallover',
#  'WAZE',
#  'bestrong',
#  'WXTX',
#  'FloodRiskReduction',
#  'catchup',
#  'prayersforRockport',
#  'FailedPresident',
#  'Charlottesville',
#  'funddrive',
#  '451Heat',
#  'rescueinfo',
#  'BlackPower',
#  'GWU',
#  'PRAYFORHOUSTON',
#  'LiarInChief',
#  'kevinhart',
#  'TexansVSSaints',
#  'skylar',
#  'raining',
#  'Aruba',
#  'ImpeachTrump',
#  'saturdaymorning',
#  'PrayForJapan',
#  'unreal',
#  'bankofamerica',
#  'Riders',
#  'chump',
#  'tornado',
#  'blows',
#  'realnews',
#  'WeAreBlood',
#  'testimonial',
#  'SaturdayMorning',
#  'breaking',
#  'ReadyPlayerOne',
#  'flashfloods',
#  'HurricanIrma',
#  'PrayingForHouston',
#  'Toxicwaste',
#  'bofa',
#  'PrincetonU',
#  'StayPrayedUp',
#  'Diabetes',
#  'JoelOlsteen',
#  'KeepYourPetsSafe',
#  'HelpRescue',
#  'thisputasmileonmyface',
#  'prayforthesepeople',
#  'magicman',
#  'ClimateAction',
#  'Baytown',
#  'STEM',
#  'logistics',
#  'LessonsFromTheStorm',
#  'hankamer',
#  'cells',
#  'HurricanHarvey',
#  'HoustonRescue',
#  'HelpMeHarvey',
#  'Senate',
#  'saftey',
#  'khou',
#  'KingTruth',
#  'happyclownsighting',
#  'blogpost',
#  'UniteAgainstHate',
#  'hypocrite',
#  'cumshow',
#  'Jaguars',
#  'wellsfargo',
#  'mfg',
#  'HurricaneIrmaRecovery',
#  'PriceGouging',
#  'betterdays',
#  'Sugarland',
#  'Damage',
#  'rushlimbaugh',
#  'eBay',
#  'undercover',
#  'RacistPresident',
#  'CRIMES',
#  'Barcelona',
#  'DarkChords',
#  'battendownthehatches',
#  'facepalm',
#  'found',
#  'Twittersphere',
#  'musicforhouston',
#  'eastend',
#  'arkhamasylum',
#  'bitcoin',
#  'Companies',
#  'coldplay_newsong',
#  'C1055',
#  'BlastItAll',
#  'HarveyLove',
#  'donateforanimals',
#  'Rich',
#  'lockwood',
#  'MarkCuban',
#  'USArmy',
#  'WhiteHelmets',
#  'floodvictim',
#  'truegrit',
#  'HandInHand2017',
#  'donatesupplies',
#  'warning',
#  'eyewitnessdescription',
#  'CrestHill',
#  'Toxic',
#  'China',
#  'dumb',
#  'photography',
#  'hoUSton',
#  'volunteers',
#  'off2byui',
#  'MexicanFighters',
#  'taxes',
#  'Doppler',
#  'icanteven',
#  'US',
#  'yaboislimm32',
#  'warm',
#  'AlaskaAir',
#  'WeRWithU',
#  'prolife',
#  'thesunisshining',
#  'Aransaspasstx',
#  'Astros',
#  'travelnurse',
#  'HarveyLostPets',
#  'Isurvivedkatrina',
#  'tdb',
#  'TheAviators',
#  'bush',
#  'workerversary',
#  'WoodstockChimes',
#  'resources',
#  'Dogs',
#  'TrumpsAmerica',
#  'AllenTx',
#  'Galveston',
#  'pizza',
#  'AmeriCorpsNCCC',
#  'townofwindsor',
#  'DanceParty',
#  'goals',
#  'Vegan',
#  'fracking',
#  'cnn',
#  'delayedflight',
#  'treatthemlikea4waystop',
#  'TuesdayMotivation',
#  'power',
#  'BOSproud',
#  'Canada',
#  'HuracanHarvey',
#  'Racine',
#  'FBCColumbus',
#  'IoT',
#  'hurrikan',
#  'Huston',
#  'TrumpBrokenPromises',
#  'SickNotWeak',
#  'catlover',
#  'AltRight',
#  'CQRF',
#  'IfSiriWereAMan',
#  'PRAY',
#  'Evil',
#  'ReneeBaio',
#  'SouthAfrica',
#  'givingbacktosociety',
#  'helpifyoucan',
#  'heavyrain',
#  'gocoogs',
#  'Animales360',
#  'XPOLE',
#  'HurricaneRelief',
#  'the405traffic',
#  'abc13',
#  'prayforhuston',
#  'PeaceBeStill',
#  'pray4houston',
#  'freightTrain',
#  'idiocy',
#  'racists',
#  'dog',
#  'funder',
#  'PrayersforTexas',
#  'SolarEclipse2017',
#  'furacaoharvey',
#  'LaGrangeTexas',
#  'abundance',
#  'Helpneeded',
#  'Ingleside',
#  'arpaiopardoned',
#  'Cowboys',
#  'TrumpTallTales',
#  'design',
#  'houstonmua',
#  'GreenhouseGases',
#  'Libtards',
#  'fatcs',
#  'SWMO',
#  'rescuehouston',
#  'Manuel',
#  'Online',
#  'StillStanding',
#  'PizzaForTexas',
#  'HurricanHARVEY',
#  'TXVOAD',
#  'GoEBQ',
#  'dodgers',
#  'ImWithHer',
#  'itjustgotreal',
#  'Ethiopia',
#  'Guatemala',
#  'bobcat',
#  'ShutHisMouthUP',
#  'TheWall',
#  'PrayerForHurricanHarveyVictims',
#  'FEMA',
#  'ArmyCorpofEngineers',
#  'Teacherlife',
#  'KWCares',
#  'Hangry',
#  'mythoughts',
#  'ass',
#  'blessed',
#  'dogguest',
#  'TexasLonghorns',
#  'Ecuador',
#  'Kaepernick',
#  'weneedamiracle',
#  'wheelchair',
#  'DataScience',
#  'Trumpsaysnothing',
#  'Dallas',
#  'signsofhope',
#  'godcares',
#  'ImpeachTrumpAndPence',
#  'evacueesneedhelp',
#  'superstarDawn',
#  'TexanStrong',
#  'firstresponders',
#  'Hurricane2017',
#  'trumpfail',
#  'HighContrastArtStudio',
#  'setx',
#  'montrose',
#  'ILoveMyTFCU',
#  'transgenderban',
#  'washingtonfires',
#  'VOLUNTEERS',
#  'Tropicalstorm',
#  'HurricaneHarvery',
#  'aintscared',
#  'NoBanNoWall',
#  'RedRoses',
#  'brianwilliams',
#  'TMobile',
#  'DoWhatYouCan',
#  'cleanwater',
#  'gossiptwins',
#  'realtor',
#  'hurricaneharvery',
#  'ThingsThatShouldHaveBeenDone',
#  'deals',
#  'itscoming',
#  'dialysisinahurricane',
#  'hateviolenceracism',
#  'civils',
#  'Friends',
#  'BraysBayou',
#  'hero',
#  'ObamaGolfvacationLouisiana',
#  'sad',
#  'local',
#  'KeepItInTheGround',
#  'tRump',
#  'KidLitCares',
#  'ripoff',
#  'softwoodLumber',
#  'stock',
#  'rp',
#  'manufacturer',
#  'PrayForSoutheastTexas',
#  'families',
#  'AUSTIN',
#  'FakeMedia',
#  'Beasties',
#  'Sarahah',
#  'WinnieSun',
#  'HarveyHeroes',
#  'HoustonFloods2017',
#  'WarmClimate',
#  'Urban',
#  'SanAntonio',
#  'CedarPark',
#  'WH',
#  'katytx',
#  'isittoolate',
#  'holidayinn',
#  'NoPower',
#  'WFAA8',
#  'precipitation',
#  'Tx',
#  'truth',
#  'criminals',
#  'Indianapolis',
#  'window',
#  'JiuJitsu',
#  'jailtrump',
#  'TheStorm',
#  'security',
#  'momlife',
#  'AnimalsNeedHelpToo',
#  'NationalGuard',
#  'Pedogate',
#  'RockportTX',
#  'FaceDanceChallenge',
#  'journalists',
#  'shelter',
#  'Eclipse',
#  'ArpioPardon',
#  'Believable',
#  'Physiatry',
#  'CharitableHumans',
#  'family',
#  'LakewoodChurch',
#  'HarveyNurses',
#  'girlsonbikes',
#  'NorthKoreaNuketest',
#  'FortBend',
#  'getpluggedin',
#  'Tampa',
#  'LibraryDisasterReliefFund',
#  'hurricanirma',
#  'Mnuchin',
#  'houstonPolice',
#  'Sterling',
#  'PrayForCorpus',
#  'CD45',
#  'ErinMcLeod',
#  'Nintendo',
#  'Rockport',
#  'SheriffJoe',
#  'HandOfHope',
#  'SouthTexas',
#  'artist',
#  'BigPharma',
#  'RESIST',
#  'dallas',
#  'keepthemsafe',
#  'Breaking',
#  'midtown',
#  'texasweather',
#  'elderly',
#  'pets',
#  'WaxWednesdays',
#  'att',
#  'notmypresident',
#  'gm',
#  'atx',
#  'MayweatherVsMacgregor',
#  'Hugo',
#  'despicable',
#  'Avon',
#  'GetOnnit',
#  'wednesday',
#  'givingback',
#  'helprelief',
#  'toomuchrain',
#  'StayPut',
#  'fightgsr',
#  'resist',
#  'FelizSabado',
#  'texascoast',
#  'Boyscouts',
#  'BernieSanders',
#  'Inspiration',
#  'Hornady',
#  'WorstPresidentEver',
#  'DG8NEWS',
#  'Thoughts',
#  'GodBlessTexas',
#  'chatterbeak',
#  '27on27',
#  'TexasTough',
#  'Boulder',
#  'rockportrelief',
#  'mycity',
#  '18wheelers',
#  'NYC',
#  'teamfollowback',
#  'EASYDOUGH',
#  'Design',
#  ...}

# %% [markdown]
# ### Run Dataframe through Vectorizer function to output word counts

# %%
good_info, bad_info = frequency_words(tweets, good_handles)
word_count = pd.DataFrame(bad_info, columns = ['count'])

# word_count.loc['arson']


word_count
# Out:
#                 count
# australia        2190
# relief           2027
# crisis           1358
# au               1262
# australian       1116
# ...               ...
# macfarlane          1
# macens              1
# maccaheraldsun      1
# macarthur           1
# interesse           1
#
# [22776 rows x 1 columns]
